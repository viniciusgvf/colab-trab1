# %% [markdown]
# <a href="https://colab.research.google.com/github/viniciusgvf/colab-trab1/blob/dev/Primeiro_Trabalho_Vinicius.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##CELULAR RESPONSAVE PELA PREPARAÇÃO
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.base import BaseEstimator
import pandas as pd

#Download dos dados utilizados no trabalho
# !wget -nv https://data.mendeley.com/public-files/datasets/bbmmm4wgr8/files/3516f33e-d439-493d-b94c-8121e6f5884c/file_downloaded -O data.csv
#Obtenção dos dados pelo arquiv
df = pd.read_csv('data.csv')

#Criação da classe HP
class HeterogeneousPooling(BaseEstimator):

  def __init__(self, n_samples:int):
    print('criado')
    self._nsamples = n_samples
    self._DT = DecisionTreeClassifier
    self._NB = GaussianNB()
    self._KNN = KNeighborsClassifier()
    super().__init__()

  def fit(self,X,y):
    print('treinado',self._nsamples)
    for rodadas in range(0,self._nsamples):
      if (rodadas>0):
        print("roleta")
      else:
        print("sem roleta")
      print("Rodando",rodadas)
    return self

  def predict(self,X):
    print('prevendo')
    return None #return y

teste = HeterogeneousPooling(5)

tt = teste.fit([],[])
# Out:
# 2024-05-22 17:46:38 URL:https://prod-dcd-datasets-public-files-eu-west-1.s3.eu-west-1.amazonaws.com/5ac049c1-97cf-494c-a2db-18f866d80db0 [30811/30811] -> "data.csv" [1]
# criado
# treinado 5
# sem roleta
# Rodando 0
# roleta
# Rodando 1
# roleta
# Rodando 2
# roleta
# Rodando 3
# roleta
# Rodando 4

# %%
import pandas as pd

df = pd.read_csv('data.csv')
#Serei responsavel pela TASK1 pois minha matricula termina em 0 (zero)
df.rename(columns={'TaskII': 'TaskI', 'TaskIII': 'TaskII', 'TaskIV':'TaskIII'}, inplace=True)
df.head()
# Out:
# 2024-05-12 00:43:26 URL:https://prod-dcd-datasets-public-files-eu-west-1.s3.eu-west-1.amazonaws.com/5ac049c1-97cf-494c-a2db-18f866d80db0 [30811/30811] -> "data.csv" [1]
#    public_id  lesion_id  patient_id      path localization  larger_size  \
# 0          0         50          48  0000.png       Tongue          2.0
# 1          1         50          48  0001.png       Tongue          2.0
# 2          2         41          39  0002.png       Tongue          2.5
# 3          3         41          39  0003.png       Tongue          2.5
# 4          4         87          81  0004.png          Lip          1.5
#
#   tobacco_use alcohol_consumption sun_exposure gender skin_color  age_group  \
# 0         Yes                  No           No      M      Black          2
# 1         Yes                  No           No      M      Black          2
# 2         Yes              Former          Yes      M      White          1
# ...
